# %%
  from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'drive/MyDrive/Datasets'

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/PublicSubmissions[1].csv')

# %%
print("first 5 rows of the datasets:")
print(df.head())
# Out:
# first 5 rows of the datasets:
#        id    sub_72075    sub_72143  sub_72153
# 0  188533  17174.64566  18492.69452  18283.959
# 1  188534  77717.63716  81525.85693  80079.695
# 2  188535  54798.71051  55718.00152  55735.895
# 3  188536  28910.82006  29743.66550  28824.973
# 4  188537  29142.58911  30222.72242  29655.340

# %%
print("\nBasic information about the dataset:")
print(df.info())
# Out:
# Basic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         125690 non-null  int64
#  1   sub_72075  125690 non-null  float64
#  2   sub_72143  125690 non-null  float64
#  3   sub_72153  125690 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 3.8 MB
# None

# %%
print("\nSummary statistics for numerical columns:")
print(df.describe())
# Out:
# Summary statistics for numerical columns:
#                   id      sub_72075      sub_72143      sub_72153
# count  125690.000000  125690.000000  125690.000000  125690.000000
# mean   251377.500000   43513.096980   43839.113454   43622.055721
# std     36283.722005   29766.987866   29658.147620   29668.490508
# min    188533.000000    6069.377033    9887.849240   10003.249000
# 25%    219955.250000   20586.620902   20779.473925   20394.942750
# 50%    251377.500000   37207.091950   37677.156105   37464.371000
# 75%    282799.750000   58290.984210   57841.026850   57657.174000
# max    314222.000000  418647.577400  281116.092600  268180.340000

# %%
print("\nMissing values in the dataset:")
print(df.isnull().sum())
# Out:
# Missing values in the dataset:
# id           0
# sub_72075    0
# sub_72143    0
# sub_72153    0
# dtype: int64

# %%
print("\nNumber of unique id:")
print(df['id'].nunique())
# Out:
# Number of unique id:
# 125690

# %%
print("\nid counts:")
print(df['id'].value_counts())
# Out:
# id counts:
# id
# 188533    1
# 272335    1
# 272333    1
# 272332    1
# 272331    1
#          ..
# 230426    1
# 230425    1
# 230424    1
# 230423    1
# 314222    1
# Name: count, Length: 125690, dtype: int64

# %%
print("nTop 15 most records:")
print(df.sort_values (by='id' , ascending= False).head())
# Out:
# nTop 15 most records:
#             id    sub_72075    sub_72143  sub_72153
# 125689  314222  38519.57098  36941.47550  37376.348
# 125688  314221  16902.25308  15913.43726  15950.935
# 125687  314220  20939.12270  20432.95897  20515.479
# 125686  314219  50146.61825  54749.98731  54584.523
# 125685  314218  27329.18700  27263.60712  28164.428

# %%
print("\nTop 5 least  records:")
print(df.sort_values (by='id' , ascending= True).head())
# Out:
# Top 5 least  records:
#        id    sub_72075    sub_72143  sub_72153
# 0  188533  17174.64566  18492.69452  18283.959
# 1  188534  77717.63716  81525.85693  80079.695
# 2  188535  54798.71051  55718.00152  55735.895
# 3  188536  28910.82006  29743.66550  28824.973
# 4  188537  29142.58911  30222.72242  29655.340

# %%
print("\nid with the highest sub_72143 greater than 2000:")
expensive_id = df[df['sub_72143'] >2000]
print(expensive_id)
# Out:
# id with the highest sub_72143 greater than 2000:
#             id    sub_72075    sub_72143  sub_72153
# 0       188533  17174.64566  18492.69452  18283.959
# 1       188534  77717.63716  81525.85693  80079.695
# 2       188535  54798.71051  55718.00152  55735.895
# 3       188536  28910.82006  29743.66550  28824.973
# 4       188537  29142.58911  30222.72242  29655.340
# ...        ...          ...          ...        ...
# 125685  314218  27329.18700  27263.60712  28164.428
# 125686  314219  50146.61825  54749.98731  54584.523
# 125687  314220  20939.12270  20432.95897  20515.479
# 125688  314221  16902.25308  15913.43726  15950.935
# 125689  314222  38519.57098  36941.47550  37376.348
#
# [125690 rows x 4 columns]

# %%
print("\nAverage the lowest sub_72143 for each id:")
avg_sub_72143 = df.groupby('id')['sub_72143'] .mean()
print(avg_sub_72143)
# Out:
# Average the lowest sub_72143 for each id:
# id
# 188533    18492.69452
# 188534    81525.85693
# 188535    55718.00152
# 188536    29743.66550
# 188537    30222.72242
#              ...
# 314218    27263.60712
# 314219    54749.98731
# 314220    20432.95897
# 314221    15913.43726
# 314222    36941.47550
# Name: sub_72143, Length: 125690, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
print("\nHistogram of sub_72143:")
# Out:
# Histogram of sub_72143:

# %%
print("\nScatter plot of sub_72143 vs sub_72144:")
# Out:
# Scatter plot of sub_72143 vs sub_72144:

# %%
print("\nCorrelation matrix:")
# Out:
# Correlation matrix:

# %%
print("\nBox plot of sub_72143:")
# Out:
# Box plot of sub_72143:

# %%
print(df['sub_72143'].value_counts().plot(kind='hist', bins=20, color='skyblue', edgecolor='black'))
# Out:
# Axes(0.125,0.11;0.775x0.77)
