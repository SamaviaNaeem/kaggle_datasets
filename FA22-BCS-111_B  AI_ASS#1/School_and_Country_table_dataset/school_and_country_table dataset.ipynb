# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'drive/MyDrive/Datasets'

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/school_and_country_table[1].csv')

# %%
print("first 5 rows of the datasets:")
print(df.head())
# Out:
# first 5 rows of the datasets:
#                              school_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America

# %%
print("\nBasic information about the dataset:")
print(df.info())
# Out:
# Basic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818 entries, 0 to 817
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school_name  818 non-null    object
#  1   country      818 non-null    object
# dtypes: object(2)
# memory usage: 12.9+ KB
# None

# %%
print("\nSummary statistics for numerical columns:")
print(df.describe())
# Out:
# Summary statistics for numerical columns:
#                school_name                   country
# count                  818                       818
# unique                 818                        70
# top     Harvard University  United States of America
# freq                     1                       161

# %%
print("\nMissing values in the dataset:")
print(df.isnull().sum())
# Out:
# Missing values in the dataset:
# school_name    0
# country        0
# dtype: int64

# %%
print("\nNumber of unique school_name:")
print(df['school_name'].nunique())
# Out:
# Number of unique school_name:
# 818

# %%
print("\country counts:")
print(df['country'].value_counts())
# Out:
# \country counts:
# country
# United States of America    161
# United Kingdom               78
# Japan                        41
# Germany                      39
# China                        38
#                            ...
# Luxembourg                    1
# Morocco                       1
# Macau                         1
# Iceland                       1
# Lithuania                     1
# Name: count, Length: 70, dtype: int64

# %%
print("nTop 5 most country records:")
print(df.sort_values (by='school_name' , ascending= False).head())
# Out:
# nTop 5 most country records:
#                                   school_name      country
# 505                         Örebro University       Sweden
# 47   École Polytechnique Fédérale de Lausanne  Switzerland
# 38                        École Polytechnique       France
# 99           École Normale Supérieure de Lyon       France
# 41                   École Normale Supérieure       France

# %%
print("\nschool_name with the higher country:")
expensive_school_name = df['country']
print(expensive_school_name)
# Out:
# school_name with the higher country:
# 0      United States of America
# 1      United States of America
# 2      United States of America
# 3      United States of America
# 4      United States of America
#                  ...
# 813                       China
# 814                 South Korea
# 815                      Turkey
# 816                       Japan
# 817                       Japan
# Name: country, Length: 818, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
print("\nDistribution of school_name:")
# Out:
# Distribution of school_name:

# %%
print(df['school_name'].value_counts())
# Out:
# school_name
# Harvard University                                1
# University of Parma                               1
# Marche Polytechnic University                     1
# University of Nantes                              1
# National and Kapodistrian University of Athens    1
#                                                  ..
# University of Kiel                                1
# University of Southern Denmark                    1
# University of Texas at Dallas                     1
# University of the Witwatersrand                   1
# Yokohama National University                      1
# Name: count, Length: 818, dtype: int64

# %%
print(df['school_name'].value_counts().plot(kind='hist'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print("\nTop 5 countries with the most school_name:")
# Out:
# Top 5 countries with the most school_name:
