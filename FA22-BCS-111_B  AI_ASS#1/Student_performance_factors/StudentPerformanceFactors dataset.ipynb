# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'drive/MyDrive/Datasets'

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/StudentPerformanceFactors[1].csv')

# %%
print("first 5 rows of the datasets:")
print(df.head())
# Out:
# first 5 rows of the datasets:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
# ...

# %%
print("\nBasic information about the dataset:")
print(df.info())
# Out:
# Basic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
# ...

# %%
print("\nSummary statistics for numerical columns:")
print(df.describe())
# Out:
# Summary statistics for numerical columns:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
print("\nMissing values in the dataset:")
print(df.isnull().sum())
# Out:
# Missing values in the dataset:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
print("\nNumber of unique Attendance:")
print(df['Attendance'].nunique())
# Out:
# Number of unique Attendance:
# 41

# %%
print("\nHours_Studied counts:")
print(df['Hours_Studied'].value_counts())
# Out:
# Hours_Studied counts:
# Hours_Studied
# 20    465
# 19    441
# 21    431
# 23    411
# 22    402
# 18    401
# 17    381
# 24    357
# 16    351
# 15    315
# 25    289
# 14    269
# 26    263
# 27    229
# 13    218
# 12    192
# 28    171
# 11    146
# 29    134
# 30    123
# 10     94
# 9      86
# 31     77
# 8      58
# 32     54
# 7      51
# 33     40
# 34     29
# 5      21
# 35     20
# 6      17
# 4      17
# 3      12
# 36     11
# 38      7
# 39      7
# 37      6
# 2       6
# 1       3
# 43      1
# 44      1
# Name: count, dtype: int64

# %%
print("nTop 5 most Tutoring_Sessions records:")
print(df.sort_values (by='Gender' , ascending= False).head())
# Out:
# nTop 5 most Tutoring_Sessions records:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 3855             19          65                 High              Medium
# 3846             27          91               Medium                 Low
# 3842             26          64               Medium                High
# 3840             16          85               Medium              Medium
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 3855                         No            6               55
# 3846                         No            8               57
# 3842                         No            6               91
# 3840                         No            8               87
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# ...

# %%
print("\nAverage the lowest Physical_Activity for each Previous_Scores :")
avg_Physical_Activity = df.groupby('Previous_Scores')['Physical_Activity'] .mean()
print(avg_Physical_Activity)
# Out:
# Average the lowest Physical_Activity for each Previous_Scores :
# Previous_Scores
# 50     2.951613
# 51     2.968254
# 52     3.073529
# 53     2.916667
# 54     2.794118
# 55     2.959677
# 56     2.900000
# 57     2.952000
# 58     2.933333
# 59     3.000000
# 60     2.966942
# 61     3.113821
# 62     2.959677
# 63     2.933333
# 64     3.000000
# 65     3.080882
# 66     3.042424
# 67     3.097015
# 68     3.053030
# 69     3.069767
# 70     3.066176
# 71     2.965753
# 72     2.933333
# 73     3.036232
# 74     2.873134
# 75     2.856061
# 76     3.035714
# 77     3.090164
# 78     2.923077
# 79     2.929688
# 80     3.082707
# 81     2.887097
# 82     2.978723
# 83     2.904000
# 84     3.000000
# 85     2.693333
# 86     3.000000
# 87     2.927419
# 88     2.856115
# 89     3.000000
# 90     2.756098
# 91     3.036765
# 92     3.079365
# 93     2.953488
# 94     3.006452
# 95     3.023256
# 96     2.875817
# 97     2.991304
# 98     2.847328
# 99     3.008000
# ...

# %%
import matplotlib.pyplot as plt

# %%
print("\nHistogram of Hours_Studied:")
# Out:
# Histogram of Hours_Studied:

# %%
print("\nScatter plot of Hours_Studied vs. Previous_Scores:")
# Out:
# Scatter plot of Hours_Studied vs. Previous_Scores:

# %%
print("\nBox plot of Gender vs. Previous_Scores:")
# Out:
# Box plot of Gender vs. Previous_Scores:

# %%
print("\nCount plot of Gender:")
# Out:
# Count plot of Gender:

# %%
print("\nPair plot of the dataset:")
# Out:
# Pair plot of the dataset:

# %%
avg_Physical_Activity = df.groupby('Previous_Scores')['Physical_Activity'].mean()
print(avg_Physical_Activity)
# Out:
# Previous_Scores
# 50     2.951613
# 51     2.968254
# 52     3.073529
# 53     2.916667
# 54     2.794118
# 55     2.959677
# 56     2.900000
# 57     2.952000
# 58     2.933333
# 59     3.000000
# 60     2.966942
# 61     3.113821
# 62     2.959677
# 63     2.933333
# 64     3.000000
# 65     3.080882
# 66     3.042424
# 67     3.097015
# 68     3.053030
# 69     3.069767
# 70     3.066176
# 71     2.965753
# 72     2.933333
# 73     3.036232
# 74     2.873134
# 75     2.856061
# 76     3.035714
# 77     3.090164
# 78     2.923077
# 79     2.929688
# 80     3.082707
# 81     2.887097
# 82     2.978723
# 83     2.904000
# 84     3.000000
# 85     2.693333
# 86     3.000000
# 87     2.927419
# 88     2.856115
# 89     3.000000
# 90     2.756098
# 91     3.036765
# 92     3.079365
# 93     2.953488
# 94     3.006452
# 95     3.023256
# 96     2.875817
# 97     2.991304
# 98     2.847328
# 99     3.008000
# 100    2.971014
# Name: Physical_Activity, dtype: float64

# %%
avg_plot=df.groupby('Previous_Scores')['Physical_Activity'].mean().plot(kind='hist')

# %%
print("\nScatter plot of Hours_Studied vs. Previous_Scores:")
scatter_plot = df.plot(x='Hours_Studied', y='Previous_Scores', kind='scatter')
# Out:
# Scatter plot of Hours_Studied vs. Previous_Scores:
