# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = 'drive/MyDrive/Datasets'

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/top_10_stock_data[1].csv')

# %%
print(df)
#
# Out:
#              Date Ticker        Open        High         Low       Close  \
# 0      2015-01-02   AAPL   27.847500   27.860001   26.837500   27.332500
# 1      2015-01-05   AAPL   27.072500   27.162500   26.352501   26.562500
# 2      2015-01-06   AAPL   26.635000   26.857500   26.157499   26.565001
# 3      2015-01-07   AAPL   26.799999   27.049999   26.674999   26.937500
# 4      2015-01-08   AAPL   27.307501   28.037500   27.174999   27.972500
# ...           ...    ...         ...         ...         ...         ...
# 25481  2024-08-23    LLY  955.440002  960.500000  943.109985  952.739990
# 25482  2024-08-26    LLY  949.200012  955.000000  942.770020  950.530029
# 25483  2024-08-27    LLY  952.500000  972.479980  949.950012  954.479980
# 25484  2024-08-28    LLY  954.150024  958.340027  943.260010  948.940002
# 25485  2024-08-29    LLY  955.000000  957.520020  936.000000  940.200012
#
#         Adj Close     Volume
# 0       24.373959  212818400
# 1       23.687313  257142000
# ...

# %%
print(df.head())
# Out:
#          Date Ticker       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02   AAPL  27.847500  27.860001  26.837500  27.332500  24.373959
# 1  2015-01-05   AAPL  27.072500  27.162500  26.352501  26.562500  23.687313
# 2  2015-01-06   AAPL  26.635000  26.857500  26.157499  26.565001  23.689535
# 3  2015-01-07   AAPL  26.799999  27.049999  26.674999  26.937500  24.021711
# 4  2015-01-08   AAPL  27.307501  28.037500  27.174999  27.972500  24.944679
#
#       Volume
# 0  212818400
# 1  257142000
# 2  263188400
# 3  160423600
# 4  237458000

# %%
print(df.tail())
# Out:
#              Date Ticker        Open        High         Low       Close  \
# 25481  2024-08-23    LLY  955.440002  960.500000  943.109985  952.739990
# 25482  2024-08-26    LLY  949.200012  955.000000  942.770020  950.530029
# 25483  2024-08-27    LLY  952.500000  972.479980  949.950012  954.479980
# 25484  2024-08-28    LLY  954.150024  958.340027  943.260010  948.940002
# 25485  2024-08-29    LLY  955.000000  957.520020  936.000000  940.200012
#
#         Adj Close   Volume
# 25481  952.739990  2063300
# 25482  950.530029  2166000
# 25483  954.479980  2912900
# 25484  948.940002  1701800
# 25485  940.200012  1762200

# %%
print("first 5 rows of the datasets:")
print(df.head())
# Out:
# first 5 rows of the datasets:
#          Date Ticker       Open       High        Low      Close  Adj Close  \
# 0  2015-01-02   AAPL  27.847500  27.860001  26.837500  27.332500  24.373959
# 1  2015-01-05   AAPL  27.072500  27.162500  26.352501  26.562500  23.687313
# 2  2015-01-06   AAPL  26.635000  26.857500  26.157499  26.565001  23.689535
# 3  2015-01-07   AAPL  26.799999  27.049999  26.674999  26.937500  24.021711
# 4  2015-01-08   AAPL  27.307501  28.037500  27.174999  27.972500  24.944679
#
#       Volume
# 0  212818400
# 1  257142000
# 2  263188400
# 3  160423600
# 4  237458000

# %%
print("last 5 rows of the datasets:")
print(df.tail())
# Out:
# last 5 rows of the datasets:
#              Date Ticker        Open        High         Low       Close  \
# 25481  2024-08-23    LLY  955.440002  960.500000  943.109985  952.739990
# 25482  2024-08-26    LLY  949.200012  955.000000  942.770020  950.530029
# 25483  2024-08-27    LLY  952.500000  972.479980  949.950012  954.479980
# 25484  2024-08-28    LLY  954.150024  958.340027  943.260010  948.940002
# 25485  2024-08-29    LLY  955.000000  957.520020  936.000000  940.200012
#
#         Adj Close   Volume
# 25481  952.739990  2063300
# 25482  950.530029  2166000
# 25483  954.479980  2912900
# 25484  948.940002  1701800
# 25485  940.200012  1762200

# %%
print("shape of the datasets:")
print(df.shape)
# Out:
# shape of the datasets:
# (25486, 8)

# %%
print("size of the datasets:")
print(df.size)
# Out:
# size of the datasets:
# 203888

# %%
print("columns of the datasets:")
print(df.columns)
# Out:
# columns of the datasets:
# Index(['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume'],
#       dtype='object')

# %%
print("information of the datasets:")
print(df.info())
# Out:
# information of the datasets:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25486 entries, 0 to 25485
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       25486 non-null  object
#  1   Ticker     25486 non-null  object
#  2   Open       25486 non-null  float64
#  3   High       25486 non-null  float64
#  4   Low        25486 non-null  float64
#  5   Close      25486 non-null  float64
#  6   Adj Close  25486 non-null  float64
#  7   Volume     25486 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1.6+ MB
# None

# %%
print("describe of the datasets:")
print(df.describe())
# Out:
# describe of the datasets:
#                Open          High           Low         Close     Adj Close  \
# count  25486.000000  25486.000000  25486.000000  25486.000000  25486.000000
# mean     122.880757    124.155843    121.584466    122.910798    120.838984
# std      115.447694    116.647929    114.176053    115.447702    115.470334
# min        0.481250      0.487500      0.473500      0.478500      0.459453
# 25%       39.992501     40.222501     39.664376     39.950251     38.005300
# 50%       91.272247     92.334751     90.328251     91.234249     90.031422
# 75%      165.699997    167.208370    164.027500    165.617496    164.885014
# max      956.200012    972.530029    949.950012    954.479980    954.479980
#
#              Volume
# count  2.548600e+04
# mean   7.770094e+07
# std    1.571748e+08
# min    0.000000e+00
# 25%    7.839552e+06
# 50%    2.504400e+07
# 75%    6.082800e+07
# max    3.692928e+09

# %%
avg_High=df['High'].mean()
print("average of the High:")
print(avg_High)
# Out:
# average of the High:
# 124.15584303867935

# %%
avg_Low=df['Low'].mean()
print("average of the Low:")
print(avg_Low)
# Out:
# average of the Low:
# 121.5844657633468

# %%
print("median of the High:")
print(df['High'].median())
# Out:
# median of the High:
# 92.33475112915039

# %%
print ("bar chart of the High")
df['High'].plot(kind='hist')
plt.show()
# Out:
# bar chart of the High
